# %%
import pandas as pd

# %%
# Asume que el archivo CSV se llama 'datos.csv' y está en el mismo directorio

df_dict = pd.read_csv('../dataset/goodreads_data_dictionary.csv')
df_reviews= pd.read_csv('https://huggingface.co/datasets/Pauleera/Goodreads-Book-Reviews/resolve/main/goodreads_reviews.csv')
df_books= pd.read_csv('https://huggingface.co/datasets/Pauleera/Goodreads-Book-Reviews/resolve/main/goodreads_works.csv')


# Imprime las primeras filas del DataFrame para verificar
# Out:
# /var/folders/g2/ymhyf3dx5_q5mmg521b60fh40000gn/T/ipykernel_43424/3364809258.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_reviews= pd.read_csv('https://huggingface.co/datasets/Pauleera/Goodreads-Book-Reviews/resolve/main/goodreads_reviews.csv')

# %%
df_reviews.head()
# Out:
#                           review_id                           user_id  \
# 0  fa7a00c01296e3b2b2e857d79c51ea77  3693bb4f1062b659a354848cf11ca313
# 1  de0f7c8d15e247443e51969becf2878e  3693bb4f1062b659a354848cf11ca313
# 2  e79b49504ef58b2defcdc8b79e2ec3fb  3693bb4f1062b659a354848cf11ca313
# 3  495c1210a9dbd819cbf7717dfb8b217f  3693bb4f1062b659a354848cf11ca313
# 4  54fcd8963c9dd56485d2a4ad152699c2  3693bb4f1062b659a354848cf11ca313
#
#    work_id started_at read_at               date_added  rating  \
# 0  6128277        NaN     NaN  2013-12-21 00:00:00.000     5.0
# 1  3270810        NaN     NaN  2013-12-21 00:00:00.000     5.0
# 2  4768235        NaN     NaN  2013-12-19 00:00:00.000     5.0
# 3  6264661        NaN     NaN  2013-12-16 00:00:00.000     5.0
# 4  3429537        NaN     NaN  2013-12-16 00:00:00.000     5.0
#
#                                          review_text  n_votes  n_comments
# 0  Fire is half-human and half monster. Monsters ...        0           0
# ...

# %%
df_books.head()
# Out:
#     work_id        isbn        isbn13         original_title  \
# 0   2919130  1416534601  9.781417e+12              Nocturnes
# 1  52087333         NaN           NaN              Draw Play
# 2   1649583  1416505520  9.781417e+12  Citizen of the Galaxy
# 3    688299  0060541830  9.780061e+12                  Congo
# 4   3464264  0451528824  9.780452e+12   Anne of Green Gables
#
#                author  original_publication_year  num_pages  \
# 0       John Connolly                     2004.0        NaN
# 1           Tia Lewis                     2016.0        NaN
# 2  Robert A. Heinlein                     1957.0        NaN
# 3    Michael Crichton                     1980.0        NaN
# 4     L.M. Montgomery                     1908.0        NaN
#
#                                          description  \
# 0                                                NaN
# 1  Jake:\nI can't believe my coach assigned me a ...
# 2  In a distant galaxy, the atrocity of slavery w...
# ...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143887 entries, 0 to 1143886
# Data columns (total 10 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   review_id    1143887 non-null  object
#  1   user_id      1143887 non-null  object
#  2   work_id      1143887 non-null  int64
#  3   started_at   796392 non-null   object
#  4   read_at      1031765 non-null  object
#  5   date_added   1143887 non-null  object
#  6   rating       1106569 non-null  float64
#  7   review_text  1143887 non-null  object
#  8   n_votes      1143887 non-null  int64
#  9   n_comments   1143887 non-null  int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 87.3+ MB

# %%
df_reviews.describe()
# Out:
#             work_id        rating       n_votes    n_comments
# count  1.143887e+06  1.106569e+06  1.143887e+06  1.143887e+06
# mean   1.783007e+07  3.813560e+00  2.963288e+00  8.775010e-01
# std    1.479572e+07  1.064182e+00  1.761541e+01  5.077508e+00
# min    1.040000e+02  1.000000e+00 -3.000000e+00 -1.000000e+00
# 25%    3.443248e+06  3.000000e+00  0.000000e+00  0.000000e+00
# 50%    1.595644e+07  4.000000e+00  0.000000e+00  0.000000e+00
# 75%    2.503250e+07  5.000000e+00  1.000000e+00  0.000000e+00
# max    5.771752e+07  5.000000e+00  3.222000e+03  8.330000e+02

# %%
df_books.describe()
# Out:
#             work_id        isbn13  original_publication_year     num_pages  \
# count  1.352500e+04  1.186400e+04               13507.000000  12795.000000
# mean   1.843626e+07  9.747165e+12                2003.080107    335.281907
# std    1.625871e+07  4.968387e+11                  59.253869    137.886560
# min    1.040000e+02  9.781452e+09                -500.000000      1.000000
# 25%    2.953328e+06  9.780346e+12                2006.000000    260.000000
# 50%    1.599279e+07  9.780616e+12                2011.000000    334.000000
# 75%    2.587888e+07  9.781422e+12                2014.000000    391.000000
# max    5.771752e+07  9.876543e+12                2021.000000   2201.000000
#
#        reviews_count  text_reviews_count  5_star_ratings  4_star_ratings  \
# count   1.352500e+04        13525.000000    1.352500e+04    1.352500e+04
# mean    6.144095e+04         2036.729094    1.439802e+04    1.217218e+04
# ...

# %%
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13525 entries, 0 to 13524
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   work_id                    13525 non-null  int64
#  1   isbn                       11474 non-null  object
#  2   isbn13                     11864 non-null  float64
#  3   original_title             13525 non-null  object
#  4   author                     13525 non-null  object
#  5   original_publication_year  13507 non-null  float64
#  6   num_pages                  12795 non-null  float64
#  7   description                13356 non-null  object
#  8   genres                     13525 non-null  object
#  9   image_url                  13525 non-null  object
#  10  reviews_count              13525 non-null  int64
#  11  text_reviews_count         13525 non-null  int64
#  12  5_star_ratings             13525 non-null  int64
# ...

# %%
df_books[df_books['ratings_count'] < 1000].value_counts()
# Out:
# work_id   isbn        isbn13        original_title                             author                original_publication_year  num_pages  description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
# ...

# %%
df_books[df_books["author"] == "Newt Scamander"]
# Out:
#       work_id        isbn        isbn13  \
# 3633  4195128  0439321603  9.780439e+12
#
#                                original_title          author  \
# 3633  Fantastic Beasts and Where to Find Them  Newt Scamander
#
#       original_publication_year  num_pages  \
# 3633                     2001.0       59.0
#
#                                             description  \
# 3633  Fantastic Beasts and Where to Find Them, Newt ...
#
#                                                  genres  \
# 3633  fantasy, paranormal, young-adult, fiction, chi...
#
#                                               image_url  reviews_count  \
# 3633  https://images.gr-assets.com/books/1303738520m...         377883
#
#       text_reviews_count  5_star_ratings  4_star_ratings  3_star_ratings  \
# 3633                6868           81534           67044           54564
#
#       2_star_ratings  1_star_ratings  ratings_count  avg_rating similar_books
# ...

# %%
df_books[df_books["work_id"] == 16827462]
# Out:
#        work_id        isbn        isbn13          original_title      author  \
# 9296  16827462  0525478817  9.780525e+12  The Fault in Our Stars  John Green
#
#       original_publication_year  num_pages  \
# 9296                     2012.0      313.0
#
#                                             description  \
# 9296  There is an alternate cover edition .\n"I fell...
#
#                              genres  \
# 9296  young-adult, fiction, romance
#
#                                               image_url  reviews_count  \
# 9296  https://images.gr-assets.com/books/1360206420m...        3614315
#
#       text_reviews_count  5_star_ratings  4_star_ratings  3_star_ratings  \
# 9296              142351         1351908          723931          341290
#
#       2_star_ratings  1_star_ratings  ratings_count  avg_rating  \
# 9296           96986           50541        2564656         4.3
#
#                                           similar_books
# ...

# %%
df_books[df_books['work_id'] == 66322]
# Out:
#       work_id        isbn        isbn13               original_title  \
# 2647    66322  076531178X  9.780765e+12  Mistborn : The Final Empire
#
#                  author  original_publication_year  num_pages  \
# 2647  Brandon Sanderson                     2006.0      541.0
#
#                                             description  \
# 2647  In a world where ash falls from the sky, and m...
#
#                                                  genres  \
# 2647  fantasy, paranormal, fiction, young-adult, rom...
#
#                                               image_url  reviews_count  \
# 2647  https://images.gr-assets.com/books/1480717416m...         458130
#
#       text_reviews_count  5_star_ratings  4_star_ratings  3_star_ratings  \
# 2647               16872          141438           79392           21231
#
#       2_star_ratings  1_star_ratings  ratings_count  avg_rating  \
# 2647            4134            1831         248026         4.4
#
# ...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143887 entries, 0 to 1143886
# Data columns (total 10 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   review_id    1143887 non-null  object
#  1   user_id      1143887 non-null  object
#  2   work_id      1143887 non-null  int64
#  3   started_at   796392 non-null   object
#  4   read_at      1031765 non-null  object
#  5   date_added   1143887 non-null  object
#  6   rating       1106569 non-null  float64
#  7   review_text  1143887 non-null  object
#  8   n_votes      1143887 non-null  int64
#  9   n_comments   1143887 non-null  int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 87.3+ MB
